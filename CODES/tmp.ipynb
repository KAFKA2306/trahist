# %%
csv = r'C:\Users\100ca\Documents\PyCode\TRADEHISTORY\trade_history2.csv'
import pandas as pd 
csvdata = pd.read_csv(csv)
csvdata['security_name'].unique().tolist()
# Out:
# c:\Users\100ca\miniconda3\Lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
# ['ＳＢＩ・新興国株式インデックス・ファンド(雪だるま（新興国株式）)',
#  '＜購入・換金手数料なし＞ニッセイ新興国株式インデックスファンド',
#  'eMAXIS Slim 全世界株式(オール・カントリー)',
#  'VA ENERGY',
#  'eMAXIS Slim 新興国株式インデックス',
#  'eMAXIS Slim 米国株式(S&P500)',
#  'SMT MIRAIndex エコ',
#  '＜購入・換金手数料なし＞ニッセイ 外国株式インデックスファンド',
#  'VA CONSUMER STAP',
#  'CONS STP SS SPDR',
#  'GLX ECMMERCE ETF',
#  'TELADOC HEALTH',
#  'WALT DISNEY CO',
#  'TESLA INC',
#  'LYFT INC',
#  'MARATHON DIGITAL',
#  'SPOTIFY TECH',
#  'MORGAN STANLEY',
#  'MICROSTRATEGY',
#  'ZILLOW GROUP C',
#  'SPDR GOLD MINI',
#  'UNITY SOFTWARE',
#  'COINBASE GLOBAL',
#  'TAIWAN SEMI ADR',
#  'PELOTON INTERACT',
#  'VA TTL INTL BOND',
#  'ISHARESCORE BOND',
#  'ZOOM VIDEO COMMU',
#  'ARCHER DANIELS',
#  'SPDR SP500 GRWTH',
#  'WT CH EX STATE',
#  'VNG HI DIV YIELD',
# ...

# %%
codepath =r'C:\Users\100ca\Documents\PyCode\TRADEHISTORY\DIC\securitycode.csv'
code = pd.read_csv(codepath)
print(code)

forexpath = r'C:\Users\100ca\Documents\PyCode\TRADEHISTORY\DIC\forex_data.csv'
forex = pd.read_csv(codepath)

print(forex)


tradepath = r'C:\Users\100ca\Documents\PyCode\TRADEHISTORY\trade_history2.csv'
trade = pd.read_csv(tradepath)

print(trade)
# Out:
#                          security_name security_code
# 0    ＳＢＩ・新興国株式インデックス・ファンド(雪だるま（新興国株式）)           VWO
# 1      ＜購入・換金手数料なし＞ニッセイ新興国株式インデックスファンド           VWO
# 2         eMAXIS Slim 全世界株式(オール・カントリー)            VT
# 3                            VA ENERGY           VDE
# 4              eMAXIS Slim 新興国株式インデックス           VWO
# ..                                 ...           ...
# 133             ＳＢＩ−Ｍａｎ　リキッド・トレンド・ファンド          VFMF
# 134                   iFree JPXプライム150           VTI
# 135                    NZAM・ベータ 日本REIT           VNQ
# 136     ＜購入・換金手数料なし＞ニッセイＪリートインデックスファンド           VNQ
# 137          ｉＦｒｅｅＮＥＸＴ　ＮＡＳＤＡＱ１００インデックス           QQQ
#
# [138 rows x 2 columns]
#                          security_name security_code
# 0    ＳＢＩ・新興国株式インデックス・ファンド(雪だるま（新興国株式）)           VWO
# 1      ＜購入・換金手数料なし＞ニッセイ新興国株式インデックスファンド           VWO
# 2         eMAXIS Slim 全世界株式(オール・カントリー)            VT
# 3                            VA ENERGY           VDE
# ...

# %%
print(trade)
# Out:
#      trade_date settlement_date security_code  \
# 0    2020-09-18      2020-09-25           NaN
# 1    2020-09-23      2020-10-01           NaN
# 2    2020-09-25      2020-10-01           NaN
# 3    2020-09-28      2020-10-02           NaN
# 4    2020-09-29      2020-10-05           NaN
# ..          ...             ...           ...
# 644  2024-09-09      2024-09-12           NaN
# 645  2024-09-09      2024-09-13           NaN
# 646  2024-09-09      2024-09-13           NaN
# 647  2024-09-10      2024-09-17           NaN
# 648  2024-09-10      2024-09-13           NaN
#
#                          security_name transaction_type  quantity    price  \
# 0    ＳＢＩ・新興国株式インデックス・ファンド(雪だるま（新興国株式）)            Other     494.0  10120.0
# 1      ＜購入・換金手数料なし＞ニッセイ新興国株式インデックスファンド            Other     531.0   9412.0
# 2         eMAXIS Slim 全世界株式(オール・カントリー)            Other    1798.0  11124.0
# 3         eMAXIS Slim 全世界株式(オール・カントリー)            Other    1782.0  11225.0
# ...

# %%
tradepath = r'C:\Users\100ca\Documents\PyCode\TRADEHISTORY\trade_history3.csv'
trade = pd.read_csv(tradepath)

trade

security_code
# Out:
#      trade_date settlement_date security_code  \
# 0    2020-09-18      2020-09-25           VWO
# 1    2020-09-23      2020-10-01           VWO
# 2    2020-09-25      2020-10-01            VT
# 3    2020-09-28      2020-10-02            VT
# 4    2020-09-29      2020-10-05            VT
# ..          ...             ...           ...
# 644  2024-09-09      2024-09-12           VYM
# 645  2024-09-09      2024-09-13           VNQ
# 646  2024-09-09      2024-09-13           VNQ
# 647  2024-09-10      2024-09-17           GLD
# 648  2024-09-10      2024-09-13           QQQ
#
#                          security_name transaction_type  quantity    price  \
# 0    ＳＢＩ・新興国株式インデックス・ファンド(雪だるま（新興国株式）)              Buy     494.0  10120.0
# 1      ＜購入・換金手数料なし＞ニッセイ新興国株式インデックスファンド              Buy     531.0   9412.0
# 2         eMAXIS Slim 全世界株式(オール・カントリー)              Buy    1798.0  11124.0
# 3         eMAXIS Slim 全世界株式(オール・カントリー)              Buy    1782.0  11225.0
# ...
