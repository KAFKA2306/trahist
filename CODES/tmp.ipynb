# %%
import pandas 
pandas.read_csv(r'C:\Users\100ca\Documents\PyCode\trahist\RAWDATA\rakuten\tradehistory(INVST)_20240919.csv',encoding='shift_jis')['取引'].unique()
# Out:
# array(['買付', '解約', '再投資'], dtype=object)

# %%
path = r'C:\Users\100ca\Documents\PyCode\TRADEHISTORY\integrated_trade_history_20240921.csv'
import pandas 
data = pandas.read_csv(path)#['transaction_type'].unique()
data[data['transaction_type']=='unknown']
# Out:
#      trade_date settlement_date security_code     security_name  \
# 284  2022-02-24      2022-02-24          GLDM    SPDR GOLD MINI
# 286  2022-02-24      2022-02-24          GLDM    SPDR GOLD MINI
# 301  2022-05-31      2022-06-03          CWEB  DRX CH INET BL2X
# 302  2022-05-31      2022-06-03          CWEB  DRX CH INET BL2X
# 303  2022-05-31      2022-06-03          YINN  DRX FTSE CH BL3X
# 521  2023-12-04      2023-12-07           TMF  DRX DL 20TR BL3X
#
#     transaction_type quantity price settlement_amount currency account_type  \
# 284          unknown      236     -                 -      USD           特定
# 286          unknown      118     -                 -      USD           一般
# 301          unknown        1     -                 -      USD           特定
# 302          unknown       12     -                 -      USD           特定
# 303          unknown        1     -                 -      USD           特定
# ...

# %%
path = r'C:\Users\100ca\Documents\PyCode\TRADEHISTORY\RAWDATA\rakuten\tradehistory(US)_20240919.csv'
import pandas 
data = pandas.read_csv(path,encoding='shift-jis')#['transaction_type'].unique()
import numpy as np
# 'and'を'&'に変更
data[(data['売買区分']!='買付') & (data['売買区分']!='売付')]
# Out:
#            約定日        受渡日 ティッカー               銘柄名  口座    取引区分 売買区分 信用区分 弁済期限  \
# 94   2022/2/24  2022/2/24  GLDM    SPDR GOLD MINI  一般      入庫  NaN    -    -
# 96   2022/2/24  2022/2/24  GLDM    SPDR GOLD MINI  特定      出庫  NaN    -    -
# 97   2022/5/31   2022/6/3  CWEB  DRX CH INET BL2X  特定  入庫（併合）  NaN    -    -
# 98   2022/5/31   2022/6/3  CWEB  DRX CH INET BL2X  特定  出庫（併合）  NaN    -    -
# 99   2022/5/31   2022/6/3  YINN  DRX FTSE CH BL3X  特定  出庫（併合）  NaN    -    -
# 118  2023/12/4  2023/12/7   TMF  DRX DL 20TR BL3X  特定  出庫（併合）  NaN    -    -
#
#     決済通貨  数量［株］ 単価［USドル］ 約定代金［USドル］ 為替レート 手数料［USドル］ 税金［USドル］ 受渡金額［USドル］  \
# 94     -    118        -          -     -         -        -          -
# 96     -    236        -          -     -         -        -          -
# 97     -      1        -          -     -         -        -          -
# 98     -     12        -          -     -         -        -          -
# ...
